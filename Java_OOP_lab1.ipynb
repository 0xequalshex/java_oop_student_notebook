// %% [markdown]
// # **Welcome to the lesson (demo)**

// %%
public class HelloWorld {
    public static void main(String[] args) {
        System.out.println("Hello, World!");
    }
}
// Out:
//   File "/tmp/ipython-input-4247832348.py", line 1
//     public class HelloWorld {
//            ^
// SyntaxError: invalid syntax
